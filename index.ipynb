# %%
# %%html
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/mobile-package-5669d8.css'>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/homepage-package-56904b.css'>
#
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h2><span class="section-separator-text">Analysis methods</span></h2><hr/>
#         <p>This notebook documents the steps used to analyze the data and produce figures for the associated
#         article. You can rerun the analysis steps on your own environment. You can also run the analysis on
#         a Web service provided by Jeremy Freeman's group from Janelia farm
#         <a href="http://mybinder.org/">mybinder.org team</a></p>
#       </div>
#
#       <p><a href="http://mybinder.org:/repo/margulies/gradient_analysis"><img src="http://mybinder.org/badge.svg" alt="Binder" title="" /></a></p>
#
#       <!--Comment: to change the color of the title or section, change the second h2 class argument and the third div
#             argument to either science, computing, humanities, test-prep or economics-finance-domain-->
#
#       <!--to change the number of rows per column, change the last number in 'pure-u-1-3'.
#        For example, to have three columns, change the value to 'pure-u-1-3'-->
#
#       <h2 class="domain-header economics-finance-domain"><a class="domain-title">Data preparation</a></h2>
#       <p>These notebooks encode how the data were generated from existing available datasets. We use data
#         from the <a href="http://www.humanconnectome.org/">Human Connectome Project</a> and Cocomac database.
#         </p>
#       <div class="pure-g domain-table-container economics-finance-domain">
#         <a class="subject-link pure-u-1-4" target="_blank" href="01_create_human_connectome.ipynb">Create human connectome</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="01_create_macaque_connectome.ipynb">Create macaque connectome</a>
#       </div>
#
#       <h2 class="domain-header humanities"><a class="domain-title">Embedding data</a></h2>
#       <p>This notebook describes</p>
#       <div class="pure-g domain-table-container humanities">
#         <a class="subject-link pure-u-1-4" target="_blank" href="02_embed_connectomes.ipynb">Python</a>
#       </div>
#
#       <h2 class="domain-header computing"><a class="domain-title">Advanced Applications</a></h2>
#       <div class="pure-g domain-table-container computing">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_execution_configuration.ipynb">Execution Configuration</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_resources_and_profiling.ipynb">Resource Scheduling and Profiling</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_commandline.ipynb">Commandline</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_caching.ipynb">Caching</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_databases.ipynb">Connect to Databases</a>
#       </div>
#       <p>This section will bring you further down the rabbit hole and will help you to unleash neuroimaging powers
#         that you didn't know that existed.</p>
#
#       <h2 class="domain-header math"><a class="domain-title">Useful Resources</a></h2>
#       <div class="pure-g domain-table-container math">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/resources_installation.ipynb">Installation of Nipype*</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/resources_faq.ipynb">FAQ</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/resources_resources.ipynb">Usefull Resources</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/resources_help.ipynb">Help</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/resources_python_cheat_sheet.ipynb">Python Cheat Sheet</a>
#       </div>
#       <p>This section will give you helpfull links and resources, so that you always know where to go to should you ever get stuck
#         with this tutorial.</p>
#
#       <h2 class="domain-header test-prep"><a class="domain-title">Development</a></h2>
#       <div class="pure-g domain-table-container test-prep">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/development_report_issue.ipynb">Report an Issue*</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/development_github.ipynb">Submit Code via Github*</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/development_tutorial.ipynb">Future Tutorial Ideas</a>
#       </div>
#       <p>This section will show you how to become part of the Nipype community and how to contribute to Nipype and this tutorial.</p>
#
#     </div>
#   </article>
# </body>
#
# <!--The following code will cause the code cell to disappear-->
#
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <hr/>
#
# <h2>You want to help with this tutorial?</h2>
# <p>You can find the github repo of this tutorial under <a href="https://github.com/miykael/nipype_tutorial">https://github.com/miykael/nipype_tutorial</a>.
#     Feel free to send us a pull request or leave us an <a href="https://github.com/miykael/nipype_tutorial/issues">issue</a>  with your feedback or ideas.
# </p>
#
# An alternative option to reach us is via the slack channel
# <a href="https://brainhack.slack.com/messages/nipype/">https://brainhack.slack.com/messages/nipype/</a>.</p>
# Click on the following button to access the tree structure of this notebook:
#     <form action="../tree" target="_blank"><input type="submit" value="Show Notebook Tree"></form></p>
#     The layout of this page was adapted from <a href="www.khanacademy.org/library">www.khanacademy.org/library</a>.
#     To inspect the corresponding html code, click on:
#     <form action="javascript:code_toggle()">
#         <input type="submit" value="Show HTML code">
#     </form>
# Out:
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/mobile-package-5669d8.css'>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/homepage-package-56904b.css'>
#
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h2><span class="section-separator-text">Analysis methods</span></h2><hr/>
#         <p>This notebook documents the steps used to analyze the data and produce figures for the associated
#         article. You can rerun the analysis steps on your own environment. You can also run the analysis on
#         a Web service provided by Jeremy Freeman's group from Janelia farm
#         <a href="http://mybinder.org/">mybinder.org team</a></p>
#       </div>
#
# ...
